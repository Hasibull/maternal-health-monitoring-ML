# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_column", None)
pd.set_option("display.max_row", None)

# %%
val = ['No A & D', 'Low A & D', 'Medium A & D', 'High A & D']
d = [0.78, 0.43, 0.433, 0.431]

# %%
plt.figure(figsize=(5, 3))
x = np.arange(len(val))
xc = x
w = 0.2
plt.bar(x, d, width=w, label='Decision Tree -> Postpartum')
plt.xticks(xc, val)
plt.legend()
plt.ylim(0.0, 1.0)
# Out:
# (0.0, 1.0)

# %%
val = ['No A & D', 'Low A & D', 'Medium A & D', 'High A & D']
d = [0.78, 0.48, 0.60, 0.75]

# %%
plt.figure(figsize=(5, 3))
x = np.arange(len(val))
xc = x
w = 0.2
plt.bar(x, d, width=w, label='XGBoost Classifier -> Postpartum')
plt.xticks(xc, val)
plt.legend()
plt.ylim(0.0, 1.0)
# Out:
# (0.0, 1.0)

# %%
val = ['No A & D', 'Low A & D', 'Medium A & D', 'High A & D']
d = [0.75, 0.40, 0.43, 0.50]

# %%
plt.figure(figsize=(5, 3))
x = np.arange(len(val))
xc = x
w = 0.2
plt.bar(x, d, width=w, label='Random Forest -> Postpartum')
plt.xticks(xc, val)
plt.legend()
plt.ylim(0.0, 1.0)
# Out:
# (0.0, 1.0)

# %%
val = ['No A & D', 'Low A & D', 'Medium A & D', 'High A & D']
d = [0.72, 0.31, 0.25, 0.00]

# %%
plt.figure(figsize=(5, 3))
x = np.arange(len(val))
xc = x
w = 0.2
plt.bar(x, d, width=w, label='Support Vector Classifier -> Postpartum')
plt.xticks(xc, val)
plt.legend()
plt.ylim(0.0, 1.0)
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Peripartum Results bar plot

# %%
val = ['Low risk', 'Medium risk', 'High risk']
d = [0.96, 0.95, 0.90]

# %%
plt.figure(figsize=(5, 3))
x = np.arange(len(val))
xc = x
w = 0.2
plt.bar(x, d, width=w, label='XGBoost Classifier -> Peripartum')
plt.xticks(xc, val)
plt.legend()
plt.ylim(0.0, 1.0)
# Out:
# (0.0, 1.0)

# %%
val = ['Low risk', 'Medium risk', 'High risk']
d = [0.90, 0.91, 1.00]

# %%
plt.figure(figsize=(5, 3))
x = np.arange(len(val))
xc = x
w = 0.2
plt.bar(x, d, width=w, label='Random Forest -> Peripartum')
plt.xticks(xc, val)
plt.legend()
plt.ylim(0.0, 1.0)
# Out:
# (0.0, 1.0)

# %%
val = ['Low risk', 'Medium risk', 'High risk']
d = [0.79, 0.85, 0.82]

# %%
plt.figure(figsize=(5, 3))
x = np.arange(len(val))
xc = x
w = 0.2
plt.bar(x, d, width=w, label='Decision Tree -> Peripartum')
plt.xticks(xc, val)
plt.legend()
plt.ylim(0.0, 1.0)
# Out:
# (0.0, 1.0)

# %%
val = ['Low risk', 'Medium risk', 'High risk']
d = [0.81, 0.82, 0.90]

# %%
plt.figure(figsize=(5, 3))
x = np.arange(len(val))
xc = x
w = 0.2
plt.bar(x, d, width=w, label='Support Vector Classifier -> Peripartum')
plt.xticks(xc, val)
plt.legend()
plt.ylim(0.0, 1.0)
# Out:
# (0.0, 1.0)
